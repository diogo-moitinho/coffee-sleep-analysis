# %% [markdown]
# # **PROJETO**
# ## Mineração de Dados e Interpretação
#
# ### Metodologia: KDD — fases 4 a 6
#
# As fases 0 a 3 estão em `01.eda.ipynb`.
#
#
# - 4  Mineração de dados  Padrões extraídos
# - 5  Interpretação / avaliação  Conhecimento validado
# - 6  Consolidação e ação  Conhecimento posto em uso

# %% [markdown]
# # **4. MINERAÇÃO DE DADOS**

# %% [markdown]
# # **5. INTERPRETAÇÃO / AVALIAÇÃO**

# %% [markdown]
# # **6. CONSOLIDAÇÃO E AÇÃO**
